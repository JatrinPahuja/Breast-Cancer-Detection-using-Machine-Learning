# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
urlfile="https://raw.githubusercontent.com/aimlcommunity/Breast-Cancer-Detection-using-Machine-Learning/master/cancer%20dataset.csv"


data = pd.read_csv(urlfile)
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Y=LabelEncoder()
data.iloc[:,1]=labelencoder_Y.fit_transform(data.iloc[:,1].values)

# %%
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
X=data.iloc[:,2:31].values
Y=data.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# Parameters : -
#     Parameter in statstics is an important component of any statistical analysis.
#     It can be considered as numerical characteristic regarding population staitstic or statistical model.
#     Parameter never changes,because everyone or everything was surveyed,for ex if u want to find the average age of student in a class than u can ask everyone and find the mean of everyone's age.Suppose it's 20.
#     That is parameter.
#
#     But statistics varies, If u want to find average age of students in your branch or college than and u just took an refernce of avg of your class ,and guessing avg of other classes or other branches where avg can be correct or just close to correct.
#     but gets varies.Here u didnt survyed everyone u just took a guess with the help of avg of a particular class.
#
#     Gaussian Distribution: -
#     Also known as normal distribution. It is a type of continuous probability distibution important in statistics used to represent real random values/variables.  The Data is tend to be in a central value with no bias on left or right side.It forms a bell curve.
#     Normal Distribution has equal values for mean ,median and mode. i.e
#                     mean = median = mode.
#     50% alues are lesser then mean and rest 50% values are greater than mean.
#
#     Binomial Distribution: -
#     This is Discrete type of distribution.
#         It can be thought of simply the probability of success or failure outcome of a experiment or a survey for a mulitple times. This type has 2 possibility of outcomes,for ex a coin has heads and tails,exam could has pass or fail.
#
#         criterias: -
#             1.NUMBER OF OBSERVATION IS FIXED: - a coin tossed has a probabiltiy of getting a tail is 50%.
#             2. Every trial is independent : - outcome of any of the trial wont affect outcome of the next.
#             3. probabilty of success:-  Every trial has same probabilty of success.

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# Logistic Regression:-
#     Logistic Regression is used when the dependent varraible is categorical data.
#     its outcome is like 0 or 1.
#
#     for example: -
#         to predict email is spam or not. if spam than outcome is 1 or else 0.
#     In our case it can predict the cancer cell is malignant(1) or beningn(0), based on the independent variable values provided.
#
#     Logistic stricted values range 0 or 1.

# %% [markdown]
# Decision tree Classifier: -
#     It is a Supervised Machine learning.
#
#     Decsion tree consists of: -
#         nodes: - test for the value of a attribute.
#         branch: - correspond to the outvome of a test and connects to the next leaf.
#         leaf node: - predict the outcome of the test.
#
#     This tree gives the outcome in categorical manner.
#
# It is built through binary recurssive partitioning where this is a process to spilt data into partitions and then splitting up on further branches.
# It starts with the root node splits the data on the feature that reduce the uncertinity towards final decision.

# %% [markdown]
# Random Forest Classifier: -
#    Number of  Individual decission trees are combined to make random forest.
#     Each decision tree spits the predicted outcome or the class and the class with maximum votes or counts is our outcome of model prediction.
#
#     the concept behind the model is - wisdom of crowd.
